# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2023-11-24 13:34:47.803397: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-24 13:34:47.829617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-24 13:34:47.829647: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-24 13:34:47.829666: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
lista=[1,2,3,4]
print(lista[-1])
# Out:
# 4

# %%
from models.newmodel import attentionunet
from models.newmodel import adaptableattentionunet

# %%
model1 = attentionunet((256,256,1), dropout=0.2, batchnorm=True)
# Out:
# 2023-11-24 13:34:48.870825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-24 13:34:48.874643: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
model2=adaptableattentionunet((256,256,1), filters = [16, 32, 64, 128, 256], kernelsize=3, dropout=0.2, upsample_size = 2, batchnorm=True)
# Out:
# 3
# 2
# 1
# 0
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 256, 256, 1)]        0         []
#
#  conv2d_39 (Conv2D)          (None, 256, 256, 16)         160       ['input_2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 256, 256, 16)         64        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 256, 256, 16)         0         ['activation_31[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_9[0][0]']
#
#  batch_normalization_28 (Ba  (None, 256, 256, 16)         64        ['conv2d_40[0][0]']
#  tchNormalization)
#
# ...
